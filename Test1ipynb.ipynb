# %% [markdown]
# <a href="https://colab.research.google.com/github/SAaradhya/Vision-TDCM/blob/main/Test1ipynb.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Modeling the Tomato Detection

# %% [markdown]
# ##Libraries

# %%
import numpy as np
import tensorflow as tf
import matplotlib as mp
import cv2
from matplotlib import pyplot as plt

# %% [markdown]
# ##Import and Resizing

# %%
from google.colab import drive
drive.mount('/content/drive')

# %%
# Opening image
img = cv2.imread("/content/sample_data/Model/DSC_7391.JPG")

# OpenCV opens images as BRG
# but we want it as RGB and
# we also need a grayscale
# version
img_gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
img_rgb = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)

# Creates the environment
# of the picture and shows it
plt.subplot(1, 1, 1)
plt.imshow(img_gray)
plt.show()
